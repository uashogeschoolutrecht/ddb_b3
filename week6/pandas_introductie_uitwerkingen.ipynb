# %% [markdown]
# # Introductie pandas - Uitwerkingen
# Hieronder staan mogelijke uitwerkingen voor de opdrachten uit het notebook pandas_introductie.
#
# Ga eerst zelf met de opdrachten aan de slag, en kijk pas hier als je wilt controleren of je het goed gedaan hebt of als je écht niet verder kunt. Ik raad je aan om altijd eerst te googelen en te kijken of je een mogelijke uitwerking online kunt vinden. Dit is hoe datascientisten ook werken. Als je iets wilt programmeren maar de juiste code niet weet, dan ga je kijken of je het antwoord online kunt vinden. Of in een blog, op stack overflow of in de documentatie.
#
# Wil je bijvoorbeeld het gemiddelde van een kolom vinden, google dan (bijvoorbeeld) op 'pandas calcalute mean column'. Zorg dat je altijd Python of pandas (of een ander package waar je mee werkt) in je zoekopdracht zet.
#
# Merk op dat er (bijna) altijd meerder juiste oplossingen zijn. Als je iets anders gedaan hebt dan in dit notebook, maar wel het juiste antwoord hebt gevonden, is het ook goed! En vraag het na tijdens de les bij twijfel!

# %% [markdown]
# ### Opdrachten bij tutorial 1 - Uitwerkingen

# %%
import pandas as pd

# %%
import pandas as pd
cijfers_df = pd.DataFrame({"Studentnummer": [302341, 314345, 374232, 352352], "Opdracht": [5.5, 6.2, 7.1, 9.3], 
                          "Tentamen": [6.1, 4.2, 8.3, 7.8], "Geslaagd": ["Ja", "Nee", "Ja", "Ja"]})

# %%
cijfers_df
# Out:
#    Studentnummer  Opdracht  Tentamen Geslaagd
# 0         302341       5.5       6.1       Ja
# 1         314345       6.2       4.2      Nee
# 2         374232       7.1       8.3       Ja
# 3         352352       9.3       7.8       Ja

# %% [markdown]
# ### Opdrachten bij tutorial 2 - uitwerkingen

# %%
# Opdracht 1
vgsales = pd.read_csv('../data/vgsales.csv')

# %%
#Opdracht 2
vgsales.head(5)
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
#Opdracht 3
vgsales.tail(10)
# Out:
#         Rank                                               Name Platform  \
# 16588  16591                                   Mega Brain Boost       DS
# 16589  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
# 16590  16593  Eiyuu Densetsu: Sora no Kiseki Material Collec...      PSP
# 16591  16594                                Myst IV: Revelation       PC
# 16592  16595                                           Plushees       DS
# 16593  16596                 Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                      Men in Black II: Alien Escape       GC
# 16595  16598   SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                         Know How 2       DS
# 16597  16600                                   Spirits & Spells      GBA
#
#          Year         Genre              Publisher  NA_Sales  EU_Sales  \
# 16588  2008.0        Puzzle  Majesco Entertainment      0.01      0.00
# 16589  2016.0        Action        dramatic create      0.00      0.00
# 16590  2007.0  Role-Playing     Falcom Corporation      0.00      0.00
# 16591  2004.0     Adventure                Ubisoft      0.01      0.00
# 16592  2008.0    Simulation              Destineer      0.01      0.00
# 16593  2002.0      Platform                  Kemco      0.01      0.00
# 16594  2003.0       Shooter             Infogrames      0.01      0.00
# 16595  2008.0        Racing             Activision      0.00      0.00
# 16596  2010.0        Puzzle               7G//AMES      0.00      0.01
# 16597  2003.0      Platform                Wanadoo      0.01      0.00
#
#        JP_Sales  Other_Sales  Global_Sales
# 16588      0.00          0.0          0.01
# 16589      0.01          0.0          0.01
# 16590      0.01          0.0          0.01
# 16591      0.00          0.0          0.01
# 16592      0.00          0.0          0.01
# 16593      0.00          0.0          0.01
# 16594      0.00          0.0          0.01
# 16595      0.00          0.0          0.01
# 16596      0.00          0.0          0.01
# 16597      0.00          0.0          0.01

# %%
#Oprdracht 4
vgsales.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
#Opdracht 5
vgsales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# We zien dat Year, Genre en Publisher null-values bevatten.

# %%
vgsales.to_excel('/path/to/home/vgsales.xlsx', sheet_name="vgsales", index=False)

# %% [markdown]
# ### Opdrachten bij tutorial 3 - Uitwerkingen

# %%
#Opdracht 1
vgsales_EU = vgsales["EU_Sales"]
vgsales_EU.head()
# Out:
# 0    29.02
# 1     3.58
# 2    12.88
# 3    11.01
# 4     8.89
# Name: EU_Sales, dtype: float64

# %%
#Opdracht 2
vgsales_Year_not_null = vgsales[vgsales["Year"].notna()]
vgsales_Year_not_null.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
#Opdracht 3
vgsales_more_10 = vgsales[vgsales["Global_Sales"] > 10 ]
vgsales_more_10.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
#Opdracht 4
vgsales_less_05 = vgsales[vgsales["Global_Sales"] < 0.5]
vgsales_less_05.shape
# Out:
# (12580, 11)

# %% [markdown]
# Er zijn dus 12580 games waarvoor de Global Sales lager was dan een half miljoen

# %%
#Oprdracht 5
vgsales_selection = vgsales.iloc[14:50, 1:6]
vgsales_selection
# Out:
#                                             Name Platform    Year  \
# 14                                  Wii Fit Plus      Wii  2009.0
# 15                            Kinect Adventures!     X360  2010.0
# 16                            Grand Theft Auto V      PS3  2013.0
# 17                 Grand Theft Auto: San Andreas      PS2  2004.0
# 18                             Super Mario World     SNES  1990.0
# 19  Brain Age: Train Your Brain in Minutes a Day       DS  2005.0
# 20                 Pokemon Diamond/Pokemon Pearl       DS  2006.0
# 21                              Super Mario Land       GB  1989.0
# 22                           Super Mario Bros. 3      NES  1988.0
# 23                            Grand Theft Auto V     X360  2013.0
# 24                   Grand Theft Auto: Vice City      PS2  2002.0
# 25                 Pokemon Ruby/Pokemon Sapphire      GBA  2002.0
# 26                   Pokemon Black/Pokemon White       DS  2010.0
# 27   Brain Age 2: More Training in Minutes a Day       DS  2005.0
# 28                        Gran Turismo 3: A-Spec      PS2  2001.0
# 29                Call of Duty: Modern Warfare 3     X360  2011.0
# 30       Pokémon Yellow: Special Pikachu Edition       GB  1998.0
# 31                       Call of Duty: Black Ops     X360  2010.0
# 32                           Pokemon X/Pokemon Y      3DS  2013.0
# 33                     Call of Duty: Black Ops 3      PS4  2015.0
# 34                    Call of Duty: Black Ops II      PS3  2012.0
# 35                    Call of Duty: Black Ops II     X360  2012.0
# 36                Call of Duty: Modern Warfare 2     X360  2009.0
# 37                Call of Duty: Modern Warfare 3      PS3  2011.0
# 38                          Grand Theft Auto III      PS2  2001.0
# 39                       Super Smash Bros. Brawl      Wii  2008.0
# 40                       Call of Duty: Black Ops      PS3  2010.0
# 41                   Animal Crossing: Wild World       DS  2005.0
# 42                                  Mario Kart 7      3DS  2011.0
# 43                                        Halo 3     X360  2007.0
# 44                            Grand Theft Auto V      PS4  2014.0
# 45          Pokemon HeartGold/Pokemon SoulSilver       DS  2009.0
# 46                                Super Mario 64      N64  1996.0
# 47                                Gran Turismo 4      PS2  2004.0
# 48                            Super Mario Galaxy      Wii  2007.0
# 49     Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS  2014.0
#
#            Genre                    Publisher
# 14        Sports                     Nintendo
# 15          Misc       Microsoft Game Studios
# 16        Action         Take-Two Interactive
# 17        Action         Take-Two Interactive
# 18      Platform                     Nintendo
# 19          Misc                     Nintendo
# 20  Role-Playing                     Nintendo
# 21      Platform                     Nintendo
# 22      Platform                     Nintendo
# 23        Action         Take-Two Interactive
# 24        Action         Take-Two Interactive
# 25  Role-Playing                     Nintendo
# 26  Role-Playing                     Nintendo
# 27        Puzzle                     Nintendo
# 28        Racing  Sony Computer Entertainment
# 29       Shooter                   Activision
# 30  Role-Playing                     Nintendo
# 31       Shooter                   Activision
# 32  Role-Playing                     Nintendo
# 33       Shooter                   Activision
# 34       Shooter                   Activision
# 35       Shooter                   Activision
# 36       Shooter                   Activision
# 37       Shooter                   Activision
# 38        Action         Take-Two Interactive
# 39      Fighting                     Nintendo
# 40       Shooter                   Activision
# 41    Simulation                     Nintendo
# 42        Racing                     Nintendo
# 43       Shooter       Microsoft Game Studios
# 44        Action         Take-Two Interactive
# 45        Action                     Nintendo
# 46      Platform                     Nintendo
# 47        Racing  Sony Computer Entertainment
# 48      Platform                     Nintendo
# 49  Role-Playing                     Nintendo

# %%
#Opdracht 6
vgsales_2006 = vgsales[vgsales["Year"]==2006]
vgsales_2006.head()
# Out:
#      Rank                                    Name Platform    Year  \
# 0       1                              Wii Sports      Wii  2006.0
# 6       7                   New Super Mario Bros.       DS  2006.0
# 7       8                                Wii Play      Wii  2006.0
# 20     21           Pokemon Diamond/Pokemon Pearl       DS  2006.0
# 100   101  The Legend of Zelda: Twilight Princess      Wii  2006.0
#
#             Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0          Sports  Nintendo     41.49     29.02      3.77         8.46
# 6        Platform  Nintendo     11.38      9.23      6.50         2.90
# 7            Misc  Nintendo     14.03      9.20      2.93         2.85
# 20   Role-Playing  Nintendo      6.42      4.52      6.04         1.37
# 100        Action  Nintendo      3.83      2.19      0.60         0.70
#
#      Global_Sales
# 0           82.74
# 6           30.01
# 7           29.02
# 20          18.36
# 100          7.31

# %%
#Opdracht 7
vgsales_Nintendo_2008 = vgsales[(vgsales["Publisher"]=="Nintendo") & (vgsales["Year"]==2008) & (vgsales["Genre"]=="Racing")]
vgsales_Nintendo_2008
# Out:
#    Rank            Name Platform    Year   Genre Publisher  NA_Sales  \
# 2     3  Mario Kart Wii      Wii  2008.0  Racing  Nintendo     15.85
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 2     12.88      3.79         3.31         35.82

# %% [markdown]
# Dat is er maar 1, alleen Mario Kart Wii

# %% [markdown]
# ### Opdrachten bij tutorial 4 - uitwerkingen

# %%
#Opdracht 1
vgsales["Total_Sales"] = vgsales["EU_Sales"] + vgsales["NA_Sales"] + vgsales["JP_Sales"] + vgsales["Other_Sales"]

# %%
#Opdracht 2
vgsales_renamed = vgsales.rename(columns=str.lower)

# %%
vgsales_renamed.head()
# Out:
#    rank                      name platform    year         genre publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    na_sales  eu_sales  jp_sales  other_sales  global_sales  total_sales
# 0     41.49     29.02      3.77         8.46         82.74        82.74
# 1     29.08      3.58      6.81         0.77         40.24        40.24
# 2     15.85     12.88      3.79         3.31         35.82        35.83
# 3     15.75     11.01      3.28         2.96         33.00        33.00
# 4     11.27      8.89     10.22         1.00         31.37        31.38

# %% [markdown]
# ## Opdrachten bij tutorial 5 - Uitwerkingen

# %%
#Opdracht 1 
vgsales.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales   Total_Sales
# count  16598.000000  16598.000000  16598.000000
# mean       0.048063      0.537441      0.537164
# std        0.188588      1.555028      1.555151
# min        0.000000      0.010000      0.000000
# 25%        0.000000      0.060000      0.060000
# 50%        0.010000      0.170000      0.170000
# 75%        0.040000      0.470000      0.470000
# max       10.570000     82.740000     82.740000

# %% [markdown]
# We zien dat het gemiddelde van EU_Sales 0.146652 miljoen is

# %%
#Opdracht 2
vgsales[(vgsales["Publisher"]=="Electronic Arts") & (vgsales["Year"]==2010)].mean()
# Out:
# Rank            4378.352273
# Year            2010.000000
# NA_Sales           0.445909
# EU_Sales           0.354318
# JP_Sales           0.007045
# Other_Sales        0.117727
# Global_Sales       0.924773
# Total_Sales        0.925000
# dtype: float64

# %% [markdown]
# We zien dat het gemiddelde 0.924773 miljoen is.

# %%
#Opdracht 3
vgsales[(vgsales["Year"]==2016) & (vgsales["Publisher"]=="Nintendo")]["Global_Sales"].sum()
# Out:
# 3.4699999999999998

# %% [markdown]
# Dus voor 3,47 miljoen.

# %%
#Opdracht 4
vgsales.sort_values(by="Global_Sales", ascending=False).head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Total_Sales
# 0     41.49     29.02      3.77         8.46         82.74        82.74
# 1     29.08      3.58      6.81         0.77         40.24        40.24
# 2     15.85     12.88      3.79         3.31         35.82        35.83
# 3     15.75     11.01      3.28         2.96         33.00        33.00
# 4     11.27      8.89     10.22         1.00         31.37        31.38

# %% [markdown]
# Dat is Wii Sports.

# %%
#Opdracht 5
vgsales_2009 = vgsales[vgsales["Year"]==2009]
vgsales_2009_grouped = vgsales_2009.groupby("Genre").sum()
vgsales_2009_grouped["JP_Sales"]
# Out:
# Genre
# Action          11.96
# Adventure        3.35
# Fighting         3.02
# Misc             5.80
# Platform         4.84
# Puzzle           1.65
# Racing           0.50
# Role-Playing    17.07
# Shooter          1.12
# Simulation       0.95
# Sports           9.81
# Strategy         1.82
# Name: JP_Sales, dtype: float64

# %% [markdown]
# Role-Playing leverde het meeste op, 17.07 miljoen. Gevolgd door Action.

# %%
#Opdracht 6
vgsales_1985 = vgsales[vgsales["Year"]==1985]
vgsales_1985_sorted = vgsales_1985.sort_values(by="EU_Sales")
vgsales_1985_sorted.head()
# Out:
#         Rank                                 Name Platform    Year     Genre  \
# 1973    1975          Tag Team Match M.U.S.C.L.E.      NES  1985.0  Fighting
# 2020    2022                            Bomberman      NES  1985.0    Puzzle
# 3907    3909                        Wrecking Crew      NES  1985.0  Platform
# 4727    4729                              Dig Dug      NES  1985.0    Puzzle
# 15867  15870  Strongest Tokyo University Shogi DS       DS  1985.0    Action
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 1973   Namco Bandai Games      0.00       0.0      1.05          0.0
# 2020          Hudson Soft      0.18       0.0      0.85          0.0
# 3907             Nintendo      0.00       0.0      0.51          0.0
# 4727   Namco Bandai Games      0.00       0.0      0.41          0.0
# 15867               Mycom      0.00       0.0      0.02          0.0
#
#        Global_Sales  Total_Sales
# 1973           1.05         1.05
# 2020           1.03         1.03
# 3907           0.51         0.51
# 4727           0.41         0.41
# 15867          0.02         0.02

# %%
vgsales_1985_EUSales_not_zero = vgsales_1985_sorted[vgsales_1985_sorted["EU_Sales"] > 0].head()
# Out:
#         Rank           Name Platform    Year       Genre   Publisher  \
# 4337    4339   Ghostbusters     2600  1985.0      Puzzle  Activision
# 14335  14338      Alter Ego       PC  1985.0  Simulation  Activision
# 2259    2261  Balloon Fight      NES  1985.0    Platform    Nintendo
# 1260    1262    Ice Climber      NES  1985.0    Platform    Nintendo
# 2059    2061           1942      NES  1985.0     Shooter      Capcom
#
#        NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Total_Sales
# 4337       0.42      0.03      0.00         0.00          0.45         0.45
# 14335      0.00      0.03      0.00         0.01          0.03         0.04
# 2259       0.39      0.09      0.43         0.01          0.92         0.92
# 1260       0.46      0.10      0.92         0.02          1.50         1.50
# 2059       0.65      0.14      0.21         0.00          1.00         1.00

# %% [markdown]
# We zien een gedeelde laatste plek voor *Ghostbusters* en *Alter Ego*.

# %%
vgsales[vgsales["Name"].isin(["Ghostbusters", "Alter Ego"])]
# Out:
#         Rank          Name Platform    Year       Genre   Publisher  NA_Sales  \
# 4337    4339  Ghostbusters     2600  1985.0      Puzzle  Activision      0.42
# 14335  14338     Alter Ego       PC  1985.0  Simulation  Activision      0.00
#
#        EU_Sales  JP_Sales  Other_Sales  Global_Sales  Total_Sales
# 4337       0.03       0.0         0.00          0.45         0.45
# 14335      0.03       0.0         0.01          0.03         0.04

# %% [markdown]
# Wereldwijd leverde deze games 0.03 en 0.46 miljoen op.

# %%
#Opdracht 7
vgsales.groupby("Publisher")["Name"].count().sort_values(ascending=False)
# Out:
# Publisher
# Electronic Arts                 1351
# Activision                       975
# Namco Bandai Games               932
# Ubisoft                          921
# Konami Digital Entertainment     832
#                                 ...
# EON Digital Entertainment          1
# EA Games                           1
# DreamWorks Interactive             1
# Rain Games                         1
# Locus                              1
# Name: Name, Length: 578, dtype: int64

# %% [markdown]
# Dat is Electronic Arts

# %% [markdown]
# ## Opdrachten bij tutorial 7 - Uitwerkingen

# %%
#Opdracht 1
vgsales_sorted = vgsales.sort_values(by="Year")
vgsales_sorted[["Year","NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales"]].plot(x="Year", subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001DFBFA92BC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001DFC0CB3F88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001DFC0CDCD08>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001DFC0D0F948>],
#       dtype=object)

# %% [markdown]
# In het jaar 2006 zit bij alle 4 de grafieken een piek. Waarschijnlijk was er één spel dat erg goed verkocht. Laten we eens kijken hoe dit kan.

# %%
vgsales[vgsales["Year"]==2006].sort_values(by="Global_Sales", ascending=False).head()
# Out:
#      Rank                                    Name Platform    Year  \
# 0       1                              Wii Sports      Wii  2006.0
# 6       7                   New Super Mario Bros.       DS  2006.0
# 7       8                                Wii Play      Wii  2006.0
# 20     21           Pokemon Diamond/Pokemon Pearl       DS  2006.0
# 100   101  The Legend of Zelda: Twilight Princess      Wii  2006.0
#
#             Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0          Sports  Nintendo     41.49     29.02      3.77         8.46
# 6        Platform  Nintendo     11.38      9.23      6.50         2.90
# 7            Misc  Nintendo     14.03      9.20      2.93         2.85
# 20   Role-Playing  Nintendo      6.42      4.52      6.04         1.37
# 100        Action  Nintendo      3.83      2.19      0.60         0.70
#
#      Global_Sales  Total_Sales
# 0           82.74        82.74
# 6           30.01        30.01
# 7           29.02        29.01
# 20          18.36        18.35
# 100          7.31         7.32

# %% [markdown]
# Deze piek is veroorzaakt door Nintendo Wii

# %%
#Opdracht 2
vgsales.plot.scatter(x="NA_Sales", y="EU_Sales", alpha=0.5)

# %%
#Opdracht 3
vgsales_genre = vgsales.groupby("Genre").sum()
vgsales_genre.plot.bar(y=["Global_Sales"])

# %%
#Opdracht 4
vgsales_genre.plot.bar(y=["NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales"])
